# %% [markdown]
# Reading an image file and converting it to a numpy array
#
#
# Resizing an image
#
#
#
# RGB to Grayscale conversion

# %%
# getting an image using web get ,image will be saved through the directory
# !wget https://imgs.search.brave.com/PFks3rcHLzpUtIOigw_1Kgxet52lt3cp9D2HnvpICZA/rs:fit:860:0:0:0/g:ce/aHR0cHM6Ly93YWxs/cGFwZXJzLmNvbS9p/bWFnZXMvZmVhdHVy/ZWQvZGlzbmV5LXBp/Y3R1cmVzLXNwZzhr/ZnExNWo4eTgwdTku/anBn
# Out:
# --2025-03-29 16:50:09--  https://imgs.search.brave.com/PFks3rcHLzpUtIOigw_1Kgxet52lt3cp9D2HnvpICZA/rs:fit:860:0:0:0/g:ce/aHR0cHM6Ly93YWxs/cGFwZXJzLmNvbS9p/bWFnZXMvZmVhdHVy/ZWQvZGlzbmV5LXBp/Y3R1cmVzLXNwZzhr/ZnExNWo4eTgwdTku/anBn
# Resolving imgs.search.brave.com (imgs.search.brave.com)... 18.238.238.125, 18.238.238.79, 18.238.238.59, ...
# Connecting to imgs.search.brave.com (imgs.search.brave.com)|18.238.238.125|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 103565 (101K) [image/jpeg]
# Saving to: ‘anBn’
#
# anBn                100%[===================>] 101.14K  --.-KB/s    in 0.01s
#
# 2025-03-29 16:50:09 (7.50 MB/s) - ‘anBn’ saved [103565/103565]

# %% [markdown]
# Libraries that can be used for image processing:
#
#
# matplotlib.image
#
#
# Pillow
#
#
#
# OpenCV (cv2)

# %%
# importing the image module from matplotlib library

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module
img = mpimg.imread('/content/anBn')

# %%
print(img)
# Out:
# [[[102  99  94]
#   [122 119 114]
#   [118 115 108]
#   ...
#   [ 90 132 182]
#   [ 90 132 182]
#   [ 89 131 181]]
#
#  [[101  98  93]
#   [118 115 110]
#   [112 109 102]
#   ...
#   [ 90 132 182]
#   [ 90 132 182]
#   [ 89 131 181]]
#
#  [[102  99  94]
#   [116 113 108]
#   [109 106  99]
#   ...
#   [ 90 132 182]
#   [ 90 132 182]
#   [ 89 131 181]]
#
#  ...
#
#  [[ 71  77  77]
#   [ 69  75  75]
#   [ 70  75  78]
#   ...
#   [ 69 141 215]
#   [ 69 141 213]
#   [ 69 141 213]]
#
#  [[ 71  77  77]
#   [ 69  75  75]
#   [ 69  74  77]
#   ...
#   [ 69 141 215]
#   [ 69 141 213]
#   [ 69 141 213]]
#
#  [[ 71  77  77]
#   [ 68  74  74]
#   [ 69  74  77]
#   ...
#   [ 69 141 215]
#   [ 69 141 213]
#   [ 69 141 213]]]

# %%
# displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
img = Image.open('/content/anBn')
img_resized = img.resize((200, 200))

# %%
img_resized.save('image_resized.jpg')

# %%
# displaying the image from numpy array

img_res = mpimg.imread('/content/image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# here,3 means channel number. we know that,
#
# this, image is colur image..
#
#
# colour comprises of red,green,blue..

# %% [markdown]
# **Converting RGB images to Grayscale image using **

# %%
# importing OpenCV library
import cv2

# %%
img = cv2.imread('/content/anBn')

# %%
#converting image

grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %% [markdown]
# cv2.imshow() will display the image. But this will not be allowed in Google Colab.
#
# from google.colab.patches import cv2_imshow

# %%
from google.colab.patches import cv2_imshow

# %%
# displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=860x573>

# %%
# saving the grayscale image
cv2.imwrite('miki_mouse_grayscale_image.jpg', grayscale_image)
# Out:
# True
